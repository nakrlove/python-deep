# %%
#전용면적에 따른 수요량 분석 및 시각화

# %%
# 3. 전용면적별 전/월세 수요량 분석
# 면적 구간별 거래 건수 계산
demand_jeonse = df_jeonse.groupby('면적_구간').size().reset_index(name='전세_수요량')
demand_wolse = df_wolse.groupby('면적_구간').size().reset_index(name='월세_수요량')

# 4. 시각화
plt.figure(figsize=(15, 6))

# 전세 수요량 막대 그래프
plt.subplot(1, 2, 1)
plt.bar(demand_jeonse['면적_구간'].astype(str), demand_jeonse['전세_수요량'], color='skyblue')
plt.title('전용면적에 따른 전세 수요량')
plt.xlabel('전용면적 (㎡)')
plt.ylabel('거래량')
plt.xticks(rotation=45, ha='right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 3. 전용면적별 전/월세 수요량 분석
#       2 # 면적 구간별 거래 건수 계산
# ----> 3 demand_jeonse = df_jeonse.groupby('면적_구간').size().reset_index(name='전세_수요량')
#       4 demand_wolse = df_wolse.groupby('면적_구간').size().reset_index(name='월세_수요량')
#       6 # 4. 시각화
#
# NameError: name 'df_jeonse' is not defined
